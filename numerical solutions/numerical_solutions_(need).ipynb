# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Numerical Solutions (Need)</span></div>

# %% [markdown]
# ## 1 A Bucket of water

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ### 1.1 Getting a feel

# %% [markdown]
# ![](water.png)

# %%
max_time = 5                     # Maximum time (mins)
dt = .5                          # Time step (mins)
rate = 5                         # Rate (L/min)
all_volume = []                  # To keep track of all volumes
volume = 0                       # Starting volume

all_time = np.arange(start=0, stop=max_time, step=dt)

for time in all_time:
    all_volume.append(volume)    # Record volume
    dV = rate * dt               # Calculate change in volume
    volume += dV                 # Update the new volume

# Because we can...
plt.plot(all_time, all_volume)
plt.ylabel('Volume(L)')
plt.xlabel('Time(mins)')
# Out:
# Text(0.5, 0, 'Time(mins)')

# %% [markdown]
# ### 1.2 An overflowing bucket

# %%
max_time = 5                     # Maximum time (mins)
dt = .5                          # Time step (mins)
rate = 5                         # Rate (L/min)
bucket_capacity = 9              # L
all_volume = []                  # To keep track of all volumes
volume = 0                       # Starting volume

all_time = np.arange(start=0, stop=max_time, step=dt)

for time in all_time:
    all_volume.append(volume)
    dV = rate * dt
    if volume <= bucket_capacity:
        volume += dV             # Update the new volume

plt.plot(all_time, all_volume)
plt.ylabel('Volume(L)')
plt.xlabel('Time(mins)')
plt.hlines(bucket_capacity, 0, max_time, colors='grey', ls='dashed')

# %%
max_time = 5                     # Maximum time (mins)
dt = .5                          # Time step (mins)
rate = 5                         # Rate (L/min)
bucket_capacity = 9              # L

for dt in [0.5, 0.1, 0.05, 0.01, 0.001]:
    all_volume = []                  # To keep track of all volumes
    volume = 0                       # Starting volume

    all_time = np.arange(start=0, stop=max_time, step=dt)

    for time in all_time:
        all_volume.append(volume)
        dV = rate * dt
        if volume <= bucket_capacity:
            volume += dV

    plt.plot(all_time, all_volume, label=f'dt={dt}')

plt.ylabel('Volume(L)')
plt.xlabel('Time(mins)')
plt.hlines(bucket_capacity, 0, max_time, colors='grey', ls='dashed')
plt.legend()

# %%
max_time = 5                     # Maximum time (mins)
dt = .5                          # Time step (mins)
rate = 5                         # Rate (L/min)
bucket_capacity = 9              # L
all_volume = []                  # To keep track of all volumes
volume = 0                       # Starting volume

all_time = np.linspace(start=0, stop=max_time, num=round((max_time-0)/dt)+1)
print(all_time)
for time in all_time:
    all_volume.append(volume)
    dV = rate * dt
    if volume <= bucket_capacity:
        volume += dV             # Update the new volume

plt.plot(all_time, all_volume)
plt.ylabel('Volume(L)')
plt.xlabel('Time(mins)')
plt.hlines(bucket_capacity, 0, max_time, colors='grey', ls='dashed')
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]

# %%
max_time = 5                     # Maximum time (mins)
dt = .5                          # Time step (mins)
rate = 5                         # Rate (L/min)
bucket_capacity = 9              # L

for dt in [0.5, 0.1, 0.05, 0.01, 0.001]:
    all_volume = []                  # To keep track of all volumes
    volume = 0                       # Starting volume

    all_time = np.linspace(start=0, stop=max_time, num=round((max_time-0)/dt)+1)

    for time in all_time:
        all_volume.append(volume)
        dV = rate * dt
        if volume <= bucket_capacity:
            volume += dV

    plt.plot(all_time, all_volume, label=f'dt={dt}')

plt.ylabel('Volume(L)')
plt.xlabel('Time(mins)')
plt.hlines(bucket_capacity, 0, max_time, colors='grey', ls='dashed')
plt.legend()

# %% [markdown]
# ### 1.3 A leaky bucket

# %%
max_time = 5                     # Maximum time (mins)
dt = .001                        # Time step (mins)
rate = 5                         # Filling rate (L/min)
leak_rate = 1.5                  # L/min
bucket_capacity = 9              # L
all_volume = []                  # To keep track of all volumes
volume = 0                       # Starting volume

all_time = np.arange(start=0, stop=max_time, step=dt)

for time in all_time:
    all_volume.append(volume)

    dV = rate * dt
    leak_volume = leak_rate * dt
    volume -= leak_volume

    if volume <= bucket_capacity:
        volume += dV             # Update the new volume

plt.plot(all_time, all_volume)
plt.ylabel('Volume(L)')
plt.xlabel('Time(mins)')
plt.hlines(bucket_capacity, 0, max_time, colors='grey', ls='dashed')

# %% [markdown]
# ### 1.4 Let’s turn off the tap

# %%
tap_off_time = 3                 # When the tap goes off
max_time = 5                     # Maximum time (mins)
dt = .001                        # Time step (mins)
rate = 5                         # Filling rate (L/min)
leak_rate = 1.5                  # L/min
bucket_capacity = 9              # L
all_volume = []                  # To keep track of all volumes
volume = 0                       # Starting volume

all_time = np.arange(start=0, stop=max_time, step=dt)

for time in all_time:
    all_volume.append(volume)
    dV = rate * dt

    leak_volume = leak_rate * dt
    volume -= leak_volume

    if (volume <= bucket_capacity) and (time < tap_off_time):
        volume += dV             

plt.plot(all_time, all_volume)
plt.ylabel('Volume(L)')
plt.xlabel('Time(mins)')
plt.hlines(bucket_capacity, 0, max_time, colors='grey', ls='dashed')

# %% [markdown]
# ### Using while

# %%
tap_off_time = 3                 # When the tap goes off
max_time = 5                     # Maximum time (mins)
dt = .001                        # Time step (mins)
rate = 5                         # Filling rate (L/min)
leak_rate = 1.5                  # L/min
bucket_capacity = 9              # L
all_volume = []                  # To keep track of all volumes
all_time = []                    # To keep track of all times
volume = 0                       # Starting volume
time = 0

while time <= max_time:
    all_time.append(time)
    all_volume.append(volume)
    dV = rate * dt

    leak_volume = leak_rate * dt
    volume -= leak_volume

    if (volume <= bucket_capacity) and (time < tap_off_time):
        volume += dV    

    time += dt             

plt.plot(all_time, all_volume)
plt.ylabel('Volume(L)')
plt.xlabel('Time(mins)')
plt.hlines(bucket_capacity, 0, max_time, colors='grey', ls='dashed')

# %% [markdown]
# ### 1.5 A quick summary

# %% [markdown]
# We started with a bucket and slowly added more details to our story. I hope you noticed how little our code had to be altered to add these details. Also, you can easily see the ‘story’ just by looking at the code. Here you have a glimpse of the power of programming (with Python) over other methods (such as spreadsheets): simplicity of syntax, transparency of the processes and ease of making changes.
#
# I also like to point out that irrespective of how complicated the system or problem is, the strategy you need to adopt will be the same, simple one:
#
# 1. Establish a relationship that connects the changes of the variables.
# 2. Pick a starting value
# 3. Take a step, and calculate the changes.
# 4. Update the variables
# 5. Keep on going until you have the desired number of points.
# 6. If you want to improve accuracy, take smaller steps.
#
# I will remind you of this again after the next example.

# %% [markdown]
# ### 1.6 We just solved a differential equation!

# %% [markdown]
# ![](water2.png)

# %% [markdown]
# ## 2 Simulating Radioactivity

# %% [markdown]
# ### 2.1 Introduction

# %% [markdown]
# ![](radio.png)

# %% [markdown]
# ### 2.2 Approximating the differential equation

# %% [markdown]
# ![](radio2.png)

# %% [markdown]
# ### 2.3 Getting a feel

# %% [markdown]
# |Step	|Time	      |N(t)$(×10^9)$  |Δt(million years) |$ΔN(×10^9)$|
# |:----   |:-------              |:--- | :---              |:------       |
# |0	    |t0=0              |1  |0.001             |-0.142     |
# |1      |t1=t0+Δt=0.001 | 0.858 |0.001             |-0.122          |
# |2      |t2=t1+Δt=0.002     | 0.736 |0.001             |-0.105          |
# |3	    |t3=t2+Δt=0.003     | 0.632 |0.001             |-0.090          |
# |4      |t4=t3+Δt=0.004     | 0.542 |0.001             |-0.077          |
# |5      |t5=t4+Δt=0.005     | 0.465 |0.001             |-0.066          |
# |6      |t6=t5+Δt=0.006     | 0.399 |0.001             |-0.057          |

# %% [markdown]
# We will re-create this data using Python in a bit. But, for the moment, if you are still not yet very confident about how we solve differential equations, try to complete the ? of the table by hand.

# %% [markdown]
# ### 2.4 Let’s write some code

# %%
decay_constant = 142       # For 85 Rb (per Myr)
stop_fraction = 1E-3       # stop when the sample has shrunk to
                           # this fraction of the starting value
N0 = 1                     # Starting value of N (in billions of atoms)
dt = .001
time, N = 0, N0            # Starting values

all_N, all_time = [], []

while True:
    all_time.append(time)
    all_N.append(N)

    dN = -decay_constant*N*dt
    N += dN

    if N < N0*stop_fraction:
        break

    time += dt


plt.plot(all_time, all_N)
plt.ylabel('$N$')
plt.xlabel('Time(Millions of years)')
# Out:
# Text(0.5, 0, 'Time(Millions of years)')

# %% [markdown]
# ### 2.5 Some things to note about the code

# %% [markdown]
# I like to draw your attention to how I am using a True condition with the while loop. So, it will run until the end of The Universe until I break out on my own. To break out, I check if the
# N
#  has been reduced to a negligible amount which I have defined using stop_fraction.

# %% [markdown]
# ### 2.6 A quick summary

# %% [markdown]
# ![](summary.png)

# %% [markdown]
# ## Exercise 1 :  A more realistic leak

# %%
# Out:
# 351302.4682691541

# %%
tap_off_time = 3                 # When the tap goes off
max_time = 5                     # Maximum time (mins)
dt = .001                        # Time step (mins)
rate = 5                         # Filling rate (L/min)
bucket_capacity = 9              # L
all_volume = []                  # To keep track of all volumes
volume = 0                       # Starting volume

all_time = np.arange(start=0, stop=max_time, step=dt)

for time in all_time:
    all_volume.append(volume)
    dV = rate * dt
    
    def leak_rate(volume):
        h = volume/7
        speed = np.sqrt(2*98*h)
        return 0.01 * speed * 60

    leak_volume = leak_rate(volume) * dt
    volume -= leak_volume

    if (volume <= bucket_capacity) and (time < tap_off_time):
        volume += dV  

plt.figure(figsize = (6,3))
plt.plot(all_time, all_volume)
plt.ylabel('Volume(L)')
plt.xlabel('Time(mins)')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13540\2528476149.py:17: RuntimeWarning: invalid value encountered in sqrt
#   speed = np.sqrt(2*98*h)
